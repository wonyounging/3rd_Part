# %% [markdown]
# ### 이미지-픽셀 3

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("c:/workspace3/data/images/rear_garden.PNG")

print(img.shape) # height, width, channel

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
# Out:
# (496, 819, 3)

# %%
# 이미지의 특정 위치 = 픽셀(Pixel), Pixel(BGB)

(b, g, r) = img[0, 0]

print("Pixel at (0, 0) - Red: {}, Green: {}, Blue: {}".format(r, g, b))
# Out:
# Pixel at (0, 0) - Red: 18, Green: 20, Blue: 8

# %%
# ROI

ROI = img[50:100, 50:100]

plt.imshow(ROI)

# %%
# 이미지 내에서 특정한 범위만 지정하여 색상을 변경

img[50:100, 50:100] = (0, 0, 255)

plt.imshow(img)
