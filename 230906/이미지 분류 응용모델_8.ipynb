# %% [markdown]
# ### MobileNet-cifar10

# %%
import tensorflow as tf
with tf.device('/:GPU0'):
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
    x_train = x_train / 255
    x_test = x_test / 255

    model = tf.keras.applications.MobileNet(input_shape=(32, 32, 3), include_top=False, weights='imagenet')

    model.trainable = False

    t_model = tf.keras.models.Sequential([
        model,
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    t_model.summary()

    t_model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
                    loss='sparse_categorical_crossentropy',
                    metrics='accuracy')

    # Transfer Learning
    t_model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))

    # Fine-Tuning
    t_model.trainable = True
    t_model.summary()
    t_model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0001),
                    loss='sparse_categorical_crossentropy',
                    metrics='accuracy')

    t_model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 1, 1, 1024)       3228864
#  nal)
#
#  global_average_pooling2d_1   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 128)               131200
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,361,354
# Trainable params: 132,490
# Non-trainable params: 3,228,864
# _________________________________________________________________
# Epoch 1/5
# 1563/1563 [==============================] - 34s 21ms/step - loss: 2.1716 - accuracy: 0.2089 - val_loss: 2.1418 - val_accuracy: 0.2217
# Epoch 2/5
# 1563/1563 [==============================] - 31s 20ms/step - loss: 2.1376 - accuracy: 0.2260 - val_loss: 2.1299 - val_accuracy: 0.2286
# Epoch 3/5
# 1563/1563 [==============================] - 34s 22ms/step - loss: 2.1273 - accuracy: 0.2294 - val_loss: 2.1253 - val_accuracy: 0.2308
# Epoch 4/5
# 1563/1563 [==============================] - 33s 21ms/step - loss: 2.1208 - accuracy: 0.2318 - val_loss: 2.1252 - val_accuracy: 0.2317
# Epoch 5/5
# 1563/1563 [==============================] - 33s 21ms/step - loss: 2.1158 - accuracy: 0.2353 - val_loss: 2.1157 - val_accuracy: 0.2351
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 1, 1, 1024)       3228864
#  nal)
#
#  global_average_pooling2d_1   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 128)               131200
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,361,354
# Trainable params: 3,339,466
# Non-trainable params: 21,888
# _________________________________________________________________
# Epoch 1/5
# 1563/1563 [==============================] - 197s 125ms/step - loss: 2.5993 - accuracy: 0.3961 - val_loss: 1.3418 - val_accuracy: 0.5288
# Epoch 2/5
# 1563/1563 [==============================] - 203s 130ms/step - loss: 1.2413 - accuracy: 0.5708 - val_loss: 1.0408 - val_accuracy: 0.6396
# Epoch 3/5
# 1563/1563 [==============================] - 199s 128ms/step - loss: 1.0089 - accuracy: 0.6518 - val_loss: 0.8972 - val_accuracy: 0.6924
# Epoch 4/5
# 1563/1563 [==============================] - 198s 127ms/step - loss: 0.8750 - accuracy: 0.6976 - val_loss: 0.7917 - val_accuracy: 0.7330
# Epoch 5/5
# 1563/1563 [==============================] - 197s 126ms/step - loss: 0.7711 - accuracy: 0.7346 - val_loss: 0.7446 - val_accuracy: 0.7431
